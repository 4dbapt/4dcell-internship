# %% [markdown]
# # Imports

# %%
import os
import tkinter as tk
from tkinter import filedialog
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tkinter.filedialog import askdirectory
from scipy.signal import savgol_filter, find_peaks
from scipy.integrate import trapezoid
from scipy.signal import butter, filtfilt, find_peaks
from numpy.fft import fft
from scipy.stats import ttest_1samp, shapiro
import statsmodels.stats.multitest as multitest
from scipy.stats import wilcoxon

# %% [markdown]
# # Main

# %% [markdown]
# ## Load data

# %%
# Load the aggregated file on which to do the statistics

file_path = filedialog.askopenfilename()
aggregated_data=pd.read_excel(file_path)

# %% [markdown]
# ## Data reorganization

# %%
Aggregated_Columns=aggregated_data.columns

#Find number and list of different exp_wells
Exp_column=aggregated_data['Name'].values.flatten()
ExpID=[]
Exp_wellID=[]
UniqueExpWell=[]

for i in range(0,len(Exp_column)):
    ExpID.append(Exp_column[i].split('_')[0]) #we get the experiment
    Exp_well=ExpID[i] + '_'+ aggregated_data.loc[i,'Well'] #we get the tissue
    Exp_wellID.append(Exp_well) #Parameter Exp_Tissue to follow accross the different concentrations

# Add new columns to dataframe
aggregated_data['Exp']=ExpID
aggregated_data['ExpWell']=Exp_wellID

print(np.unique(Exp_wellID))
UniqueExpWell=np.unique(Exp_wellID)


#Find number and list of different concentrations
Conc = sorted(aggregated_data['Concentration'].unique())  # Sort concentrations

# Create Excel writer for output
if file_path.endswith('.xlsx'):
    output_path = file_path.replace('.xlsx', '_reorganized.xlsx')
elif file_path.endswith('.xls'):
    output_path = file_path.replace('.xls', '_reorganized.xlsx')
else:
    output_path = file_path + '_reorganized.xlsx'

with pd.ExcelWriter(output_path, engine='openpyxl') as writer:

    #Rearrange data
    for col in Aggregated_Columns:

        # Skip non-parameter columns
        if col in ['Name', 'Exp', 'Well', 'ExpWell', 'Concentration']:
            continue

        print(f"\nProcessing parameter: {col}")

        # Create sheet column names
        Sheet_columns=['Name','Exp','Well']
        col_name=col.replace(' ','_')
        
        for c in Conc:
            Sheet_columns.append(f'Conc_{c}')

        # Create empty dataframe for this parameter
        Parameter_sheet=pd.DataFrame(columns=Sheet_columns)
        
        # Process each unique experiment-well combination
        rows_data=[]
        for exp_well in UniqueExpWell:
            # Get the metadata for this exp_well (using first occurrence)
            exp_well_data = aggregated_data[aggregated_data['ExpWell'] == exp_well]
            
            if len(exp_well_data) <2:
                continue
                    
            # Get basic info (should be same for all concentrations of this exp_well)
            name = exp_well_data['Name'].iloc[1]
            exp = exp_well_data['Exp'].iloc[0]
            well = exp_well_data['Well'].iloc[0]

            # Create row data starting with metadata
            row_data = {
                'Name': name,
                'Exp': exp,
                'Well': well
            }

            # Get parameter values for each concentration
            for c in Conc:
                conc_data = exp_well_data[exp_well_data['Concentration'] == c]
                if len(conc_data) > 0:
                            param_value = conc_data[col].iloc[0]  # Take first value if multiple
                else:
                    param_value = np.nan  # No data for this concentration
                
                row_data[f'Conc_{c}'] = param_value

            rows_data.append(row_data)
        
        # Create dataframe from collected data
        Parameter_sheet = pd.DataFrame(rows_data)
        
        # print(f"Parameter sheet for {col}:")
        # print(Parameter_sheet.head())

        # Clean column name for Excel sheet name (remove special characters, limit length)
        sheet_name = col_name.replace('/', '_').replace('\\', '_').replace('*', '_')
        sheet_name = sheet_name.replace('[', '_').replace(']', '_').replace(':', '_')
        sheet_name = sheet_name.replace('?', '_').replace('|', '_')[:31]  # Excel limit
        
        # Write to Excel sheet
        Parameter_sheet.to_excel(writer, sheet_name=sheet_name, index=False)
        print(f"Sheet '{sheet_name}' created with {len(Parameter_sheet)} rows")

print(f"\nReorganized data saved to: {output_path}")

# Get statistics

# Create Excel writer for output
if file_path.endswith('.xlsx'):
    StatPath = file_path.replace('.xlsx', '_Stats.xlsx')
elif file_path.endswith('.xls'):
    StatPath = file_path.replace('.xls', '_Stats.xlsx')
else:
    StatPath = file_path + '_Stats.xlsx'

with pd.ExcelWriter(StatPath, engine='openpyxl') as writer:
    for col in Aggregated_Columns:
        if col in ['Name', 'Exp', 'Well', 'ExpWell', 'Concentration']:
            continue
        
        # Read the sheet we just created
        sheet_name = col.replace(' ', '_').replace('/', '_')[:31]
        param_data = pd.read_excel(output_path, sheet_name=sheet_name)
        stats_columns=['Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
        print(param_data.columns.tolist())
        stats_data=param_data[stats_columns]

        # Perform Shapiro-Wilk test for normality
        print(f"Shapiro-Wilk Normality Test Results for {sheet_name}:")
        NormalGlobal=True
        for conc, values in stats_data.items():
            stat, p_value = shapiro(values,nan_policy='omit')
            if p_value < 0.05:
                NormalGlobal=False
            print(f"{conc}: W = {stat:.4f}, p-value = {p_value:.4f}, Normal = {p_value > 0.05}")
        
        print(f"NormalGolbal={NormalGlobal}")

        results = pd.DataFrame(columns=['Concentration','Test','Stat','p-value','Significance'])
        tests=[]
        statval=[]
        pval=[]
        significance=[]
        concentration=[]

        # # If normal, t-test
        # if NormalGlobal==True:
        #     # Perform one-sample t-tests against baseline (1)
        #     alpha = 0.05
        #     n_tests = len(stats_data) #length of a column without NaNs
        #     bonferroni_alpha = alpha / n_tests
            

        #     print("\nOne-Sample T-Test Results (vs. baseline = 1):")
        #     for conc, values in stats_data.items():
        #         stat, p_value = ttest_1samp(values, popmean=1, nan_policy='omit')
        #         concentration.append(conc)
        #         tests.append('T-test')
        #         statval.append(stat)
        #         pval.append(p_value)
        #         significance.append(p_value < bonferroni_alpha)
        #         print(f"{conc}: t = {stat}, p-value = {p_value}, Significant = {p_value < bonferroni_alpha}")

        #     # Bonferroni correction
        #     _, pvals_corrected, _, _ = multitest.multipletests(pval, alpha=alpha, method='bonferroni')
        #     print("\nBonferroni-Corrected p-values:")
        #     for conc, p_corr in zip(stats_data.keys(), pvals_corrected):
        #         print(f"{conc}: Corrected p-value = {p_corr}, Significant = {p_corr < alpha}")


        # If not normal, wilcoxon
        # if NormalGlobal==False:
            #Perform wilcoxon test
        for conc, values in stats_data.items():
            stat, p_value = wilcoxon(values, param_data['Conc_-1'], nan_policy='omit')
            concentration.append(conc)            
            tests.append('Wilcoxon')
            statval.append(stat)
            pval.append(p_value)
            significance.append(p_value < 0.05)
            print(f"{conc} Wilcoxon: statistic = {stat}, p-value = {p_value}, Significant = {p_value < 0.05}")

        results['Concentration']=concentration
        results['Test']=tests
        results['Stat']=statval
        results['p-value']=pval
        results['Significance']=significance

        

        #   Clean column name for Excel sheet name (remove special characters, limit length)
        sheet_name2 = sheet_name.replace(' ', '_').replace('\\', '_').replace('*', '_')
        sheet_name2 = sheet_name2.replace('[', '_').replace(']', '_').replace(':', '_')
        sheet_name2 = sheet_name2.replace('?', '_').replace('|', '_')[:31]  # Excel limit

    
        results.to_excel(writer, sheet_name=sheet_name2, index=False)




# # Create CSV files for Prism import
# csv_folder = file_path.rsplit('.', 1)[0] + '_CSV_for_Prism'
# import os
# os.makedirs(csv_folder, exist_ok=True)

# for col in Aggregated_Columns:
#     if col in ['Name', 'Exp', 'Well', 'ExpWell', 'Concentration']:
#         continue
    
#     # Read the sheet we just created
#     sheet_name = col.replace(' ', '_').replace('/', '_')[:31]
#     param_data = pd.read_excel(output_path, sheet_name=sheet_name)
    
#     # Create Prism format
#     prism_data = param_data.drop(['Name', 'Exp', 'Well'], axis=1, errors='ignore')
#     row_labels = param_data['Exp'].astype(str) + '_' + param_data['Well'].astype(str)
#     prism_data.insert(0, 'Sample', row_labels)
    
#     # Save as CSV
#     csv_path = os.path.join(csv_folder, f"{sheet_name}.csv")
#     prism_data.to_csv(csv_path, index=False)
#     print(f"CSV created: {csv_path}")
# Out:
# ['260824_E3b' '260824_E3d' '260824_E3e' '260824_E3f' '260824_E3h'
#  '260824_F3b' '260824_F3d' '260824_F3e' '260824_F3g' '260824_F3h'
#  '260824_G3a' '260824_G3c' '260824_G3d' '260824_G3f' '260824_G3g'
#  '260824_G3h' '260824_G3i' '310724_E3d' '310724_E3e' '310724_E3h'
#  '310724_F3d' '310724_F3e' '310724_F3h' '310724_F3i' '310724_G3c'
#  '310724_G3d' '310724_G3e' '310724_G3g' '310724_G3h' '310724_G3i']
#
# Processing parameter: Total video time
# Sheet 'Total_video_time' created with 30 rows
#
# Processing parameter: SNR
# Sheet 'SNR' created with 30 rows
#
# Processing parameter: Initial Youngs Modulus
# Sheet 'Initial_Youngs_Modulus' created with 30 rows
#
# Processing parameter: Days in culture
# Sheet 'Days_in_culture' created with 30 rows
#
# Processing parameter: Period (s)
# Sheet 'Period_(s)' created with 30 rows
#
# Processing parameter: Beating Frequency (Hz)
# Sheet 'Beating_Frequency_(Hz)' created with 30 rows
#
# Processing parameter: Interpeak irregularity (s)
# Sheet 'Interpeak_irregularity_(s)' created with 30 rows
#
# Processing parameter: N_twitch
# Sheet 'N_twitch' created with 30 rows
#
# Processing parameter: Contraction strain (A.U.)
# Sheet 'Contraction_strain_(A.U.)' created with 30 rows
#
# Processing parameter: Maximum contraction speed (A.U./s)
# Sheet 'Maximum_contraction_speed_(A.U.' created with 30 rows
#
# Processing parameter: Maximum relaxation speed (A.U./s)
# Sheet 'Maximum_relaxation_speed_(A.U._' created with 30 rows
#
# Processing parameter: Contraction stress (mN/mm2)
# Sheet 'Contraction_stress_(mN_mm2)' created with 30 rows
#
# Processing parameter: Contraction time (s)
# Sheet 'Contraction_time_(s)' created with 30 rows
#
# Processing parameter: Relaxation time (s)
# Sheet 'Relaxation_time_(s)' created with 30 rows
#
# Processing parameter: Contraction-relaxation time (s)
# Sheet 'Contraction-relaxation_time_(s)' created with 30 rows
#
# Processing parameter: Contraction time 10 (s)
# Sheet 'Contraction_time_10_(s)' created with 30 rows
#
# Processing parameter: Relaxation time 10 (s)
# Sheet 'Relaxation_time_10_(s)' created with 30 rows
#
# Processing parameter: Contraction time 50 (s)
# Sheet 'Contraction_time_50_(s)' created with 30 rows
#
# Processing parameter: Relaxation time 50 (s)
# Sheet 'Relaxation_time_50_(s)' created with 30 rows
#
# Processing parameter: Contraction time 90 (s)
# Sheet 'Contraction_time_90_(s)' created with 30 rows
#
# Processing parameter: Relaxation time 90 (s)
# Sheet 'Relaxation_time_90_(s)' created with 30 rows
#
# Reorganized data saved to: Z:/RnD/Baptiste/Example analyses/Contractility/Input/Dis_AK06-AK07_Pooled_Trié_reorganized.xlsx
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Total_video_time:
# Conc_1: W = 1.0000, p-value = 1.0000, Normal = True
# Conc_2: W = 1.0000, p-value = 1.0000, Normal = True
# Conc_3: W = 1.0000, p-value = 1.0000, Normal = True
# Conc_4: W = 1.0000, p-value = 1.0000, Normal = True
# NormalGolbal=True
# Conc_1 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# Conc_2 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# Conc_3 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# Conc_4 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for SNR:
# Conc_1: W = 0.5717, p-value = 0.0000, Normal = False
# Conc_2: W = 0.6955, p-value = 0.0000, Normal = False
# Conc_3: W = 0.7955, p-value = 0.0001, Normal = False
# Conc_4: W = 0.9770, p-value = 0.7423, Normal = True
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 184.0, p-value = 0.3284698575735092, Significant = False
# Conc_2 Wilcoxon: statistic = 192.0, p-value = 0.4161298982799053, Significant = False
# Conc_3 Wilcoxon: statistic = 191.0, p-value = 0.40449450351297855, Significant = False
# Conc_4 Wilcoxon: statistic = 1.0, p-value = 3.725290298461914e-09, Significant = True
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Initial_Youngs_Modulus:
# Conc_1: W = 1.0000, p-value = 1.0000, Normal = True
# Conc_2: W = 1.0000, p-value = 1.0000, Normal = True
# Conc_3: W = 1.0000, p-value = 1.0000, Normal = True
# Conc_4: W = 1.0000, p-value = 1.0000, Normal = True
# NormalGolbal=True
# Conc_1 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# Conc_2 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# Conc_3 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# Conc_4 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Days_in_culture:
# Conc_1: W = 1.0000, p-value = 1.0000, Normal = True
# Conc_2: W = 1.0000, p-value = 1.0000, Normal = True
# Conc_3: W = 1.0000, p-value = 1.0000, Normal = True
# Conc_4: W = 1.0000, p-value = 1.0000, Normal = True
# NormalGolbal=True
# Conc_1 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# Conc_2 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# Conc_3 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# Conc_4 Wilcoxon: statistic = 0.0, p-value = nan, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Period_(s):
# Conc_1: W = 0.3056, p-value = 0.0000, Normal = False
# Conc_2: W = 0.4433, p-value = 0.0000, Normal = False
# Conc_3: W = 0.6388, p-value = 0.0000, Normal = False
# Conc_4: W = 0.9303, p-value = 0.4841, Normal = True
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 149.0, p-value = 0.3483276069164276, Significant = False
# Conc_2 Wilcoxon: statistic = 88.0, p-value = 0.07872927188873291, Significant = False
# Conc_3 Wilcoxon: statistic = 33.0, p-value = 0.00018787384033203125, Significant = True
# Conc_4 Wilcoxon: statistic = 12.0, p-value = 0.25, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Beating_Frequency_(Hz):
# Conc_1: W = 0.4281, p-value = 0.0000, Normal = False
# Conc_2: W = 0.7012, p-value = 0.0000, Normal = False
# Conc_3: W = 0.7967, p-value = 0.0002, Normal = False
# Conc_4: W = 0.8400, p-value = 0.0578, Normal = True
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 147.0, p-value = 0.324220210313797, Significant = False
# Conc_2 Wilcoxon: statistic = 84.0, p-value = 0.060427069664001465, Significant = False
# Conc_3 Wilcoxon: statistic = 49.0, p-value = 0.0014527440071105957, Significant = True
# Conc_4 Wilcoxon: statistic = 17.0, p-value = 0.5703125, Significant = False
# c:\Users\inesb\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\inesb\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_wilcoxon.py:172: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
# c:\Users\inesb\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\inesb\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_wilcoxon.py:172: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
# c:\Users\inesb\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\inesb\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_wilcoxon.py:172: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
# Exception ignored in: <function ZipFile.__del__ at 0x00000166F5017010>
# Traceback (most recent call last):
#   File "c:\Users\inesb\AppData\Local\Programs\Python\Python310\lib\zipfile.py", line 1821, in __del__
#     self.close()
#   File "c:\Users\inesb\AppData\Local\Programs\Python\Python310\lib\zipfile.py", line 1838, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file
# Exception ignored in: <function ZipFile.__del__ at 0x00000166F5017010>
# Traceback (most recent call last):
#   File "c:\Users\inesb\AppData\Local\Programs\Python\Python310\lib\zipfile.py", line 1821, in __del__
#     self.close()
#   File "c:\Users\inesb\AppData\Local\Programs\Python\Python310\lib\zipfile.py", line 1838, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Interpeak_irregularity_(s):
# Conc_1: W = 0.9603, p-value = 0.3747, Normal = True
# Conc_2: W = 0.4426, p-value = 0.0000, Normal = False
# Conc_3: W = 0.7639, p-value = 0.0001, Normal = False
# Conc_4: W = 0.6852, p-value = 0.0010, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 55.0, p-value = 0.0007440149784088135, Significant = True
# Conc_2 Wilcoxon: statistic = 129.0, p-value = 0.5645889043807983, Significant = False
# Conc_3 Wilcoxon: statistic = 59.0, p-value = 0.0041751861572265625, Significant = True
# Conc_4 Wilcoxon: statistic = 0.0, p-value = 0.00390625, Significant = True
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for N_twitch:
# Conc_1: W = 0.5970, p-value = 0.0000, Normal = False
# Conc_2: W = 0.4012, p-value = 0.0000, Normal = False
# Conc_3: W = 0.6723, p-value = 0.0000, Normal = False
# Conc_4: W = 0.5746, p-value = 0.0000, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 71.0, p-value = 0.5277266198659963, Significant = False
# Conc_2 Wilcoxon: statistic = 88.0, p-value = 0.33882696734177975, Significant = False
# Conc_3 Wilcoxon: statistic = 123.0, p-value = 0.04098406876723113, Significant = True
# Conc_4 Wilcoxon: statistic = 125.0, p-value = 0.07561937029590762, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Contraction_strain_(A.U.):
# Conc_1: W = 0.8171, p-value = 0.0003, Normal = False
# Conc_2: W = 0.9036, p-value = 0.0257, Normal = False
# Conc_3: W = 0.9593, p-value = 0.4001, Normal = True
# Conc_4: W = 0.8159, p-value = 0.0310, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 150.0, p-value = 0.3607836216688156, Significant = False
# Conc_2 Wilcoxon: statistic = 73.0, p-value = 0.026927709579467773, Significant = True
# Conc_3 Wilcoxon: statistic = 2.0, p-value = 1.7881393432617188e-07, Significant = True
# Conc_4 Wilcoxon: statistic = 0.0, p-value = 0.00390625, Significant = True
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Maximum_contraction_speed_(A.U.:
# Conc_1: W = 0.8150, p-value = 0.0003, Normal = False
# Conc_2: W = 0.9484, p-value = 0.2506, Normal = True
# Conc_3: W = 0.9207, p-value = 0.0531, Normal = True
# Conc_4: W = 0.8273, p-value = 0.0417, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 177.0, p-value = 0.7857417166233063, Significant = False
# Conc_2 Wilcoxon: statistic = 147.0, p-value = 0.944107174873352, Significant = False
# Conc_3 Wilcoxon: statistic = 3.0, p-value = 2.980232238769531e-07, Significant = True
# Conc_4 Wilcoxon: statistic = 0.0, p-value = 0.00390625, Significant = True
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Maximum_relaxation_speed_(A.U._:
# Conc_1: W = 0.8728, p-value = 0.0034, Normal = False
# Conc_2: W = 0.8622, p-value = 0.0037, Normal = False
# Conc_3: W = 0.9836, p-value = 0.9456, Normal = True
# Conc_4: W = 0.8456, p-value = 0.0667, Normal = True
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 147.0, p-value = 0.324220210313797, Significant = False
# Conc_2 Wilcoxon: statistic = 129.0, p-value = 0.5645889043807983, Significant = False
# Conc_3 Wilcoxon: statistic = 0.0, p-value = 5.960464477539063e-08, Significant = True
# Conc_4 Wilcoxon: statistic = 0.0, p-value = 0.00390625, Significant = True
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Contraction_stress_(mN_mm2):
# Conc_1: W = 0.8171, p-value = 0.0003, Normal = False
# Conc_2: W = 0.9036, p-value = 0.0257, Normal = False
# Conc_3: W = 0.9593, p-value = 0.4001, Normal = True
# Conc_4: W = 0.8159, p-value = 0.0310, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 150.0, p-value = 0.3607836216688156, Significant = False
# Conc_2 Wilcoxon: statistic = 73.0, p-value = 0.026927709579467773, Significant = True
# Conc_3 Wilcoxon: statistic = 2.0, p-value = 1.7881393432617188e-07, Significant = True
# Conc_4 Wilcoxon: statistic = 0.0, p-value = 0.00390625, Significant = True
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Contraction_time_(s):
# Conc_1: W = 0.3570, p-value = 0.0000, Normal = False
# Conc_2: W = 0.8269, p-value = 0.0008, Normal = False
# Conc_3: W = 0.8582, p-value = 0.0025, Normal = False
# Conc_4: W = 0.7444, p-value = 0.0047, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 171.0, p-value = 0.6789510101079941, Significant = False
# Conc_2 Wilcoxon: statistic = 116.0, p-value = 0.344876766204834, Significant = False
# Conc_3 Wilcoxon: statistic = 85.0, p-value = 0.036682069301605225, Significant = True
# Conc_4 Wilcoxon: statistic = 21.0, p-value = 0.91015625, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Relaxation_time_(s):
# Conc_1: W = 0.6051, p-value = 0.0000, Normal = False
# Conc_2: W = 0.9190, p-value = 0.0556, Normal = True
# Conc_3: W = 0.9298, p-value = 0.0860, Normal = True
# Conc_4: W = 0.7053, p-value = 0.0016, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 163.0, p-value = 0.5460176914930344, Significant = False
# Conc_2 Wilcoxon: statistic = 135.0, p-value = 0.6839864253997803, Significant = False
# Conc_3 Wilcoxon: statistic = 142.0, p-value = 0.5964998602867126, Significant = False
# Conc_4 Wilcoxon: statistic = 10.0, p-value = 0.1640625, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Contraction-relaxation_time_(s):
# Conc_1: W = 0.4927, p-value = 0.0000, Normal = False
# Conc_2: W = 0.9389, p-value = 0.1544, Normal = True
# Conc_3: W = 0.9636, p-value = 0.4907, Normal = True
# Conc_4: W = 0.8237, p-value = 0.0379, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 174.0, p-value = 0.7317177355289459, Significant = False
# Conc_2 Wilcoxon: statistic = 127.0, p-value = 0.5270590782165527, Significant = False
# Conc_3 Wilcoxon: statistic = 158.0, p-value = 0.9158032536506653, Significant = False
# Conc_4 Wilcoxon: statistic = 15.0, p-value = 0.42578125, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Contraction_time_10_(s):
# Conc_1: W = 0.9583, p-value = 0.3375, Normal = True
# Conc_2: W = 0.9346, p-value = 0.1233, Normal = True
# Conc_3: W = 0.9496, p-value = 0.2453, Normal = True
# Conc_4: W = 0.8889, p-value = 0.1943, Normal = True
# NormalGolbal=True
# Conc_1 Wilcoxon: statistic = 158.0, p-value = 0.4698396325111389, Significant = False
# Conc_2 Wilcoxon: statistic = 110.0, p-value = 0.26434290409088135, Significant = False
# Conc_3 Wilcoxon: statistic = 121.0, p-value = 0.2751842737197876, Significant = False
# Conc_4 Wilcoxon: statistic = 0.0, p-value = 0.00390625, Significant = True
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Relaxation_time_10_(s):
# Conc_1: W = 0.7468, p-value = 0.0000, Normal = False
# Conc_2: W = 0.8619, p-value = 0.0037, Normal = False
# Conc_3: W = 0.8562, p-value = 0.0023, Normal = False
# Conc_4: W = 0.7291, p-value = 0.0031, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 185.0, p-value = 0.9340859353542328, Significant = False
# Conc_2 Wilcoxon: statistic = 62.0, p-value = 0.010507822036743164, Significant = True
# Conc_3 Wilcoxon: statistic = 104.0, p-value = 0.11993378400802612, Significant = False
# Conc_4 Wilcoxon: statistic = 11.0, p-value = 0.203125, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Contraction_time_50_(s):
# Conc_1: W = 0.9369, p-value = 0.1022, Normal = True
# Conc_2: W = 0.9133, p-value = 0.0416, Normal = False
# Conc_3: W = 0.9264, p-value = 0.0718, Normal = True
# Conc_4: W = 0.7481, p-value = 0.0052, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 180.0, p-value = 0.8407831341028214, Significant = False
# Conc_2 Wilcoxon: statistic = 136.0, p-value = 0.704756498336792, Significant = False
# Conc_3 Wilcoxon: statistic = 109.0, p-value = 0.15633821487426758, Significant = False
# Conc_4 Wilcoxon: statistic = 12.0, p-value = 0.25, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Relaxation_time_50_(s):
# Conc_1: W = 0.4069, p-value = 0.0000, Normal = False
# Conc_2: W = 0.9065, p-value = 0.0296, Normal = False
# Conc_3: W = 0.8108, p-value = 0.0003, Normal = False
# Conc_4: W = 0.6716, p-value = 0.0007, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 155.0, p-value = 0.4270208328962326, Significant = False
# Conc_2 Wilcoxon: statistic = 55.0, p-value = 0.005330443382263184, Significant = True
# Conc_3 Wilcoxon: statistic = 134.0, p-value = 0.457846462726593, Significant = False
# Conc_4 Wilcoxon: statistic = 14.0, p-value = 0.359375, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Contraction_time_90_(s):
# Conc_1: W = 0.3556, p-value = 0.0000, Normal = False
# Conc_2: W = 0.7869, p-value = 0.0002, Normal = False
# Conc_3: W = 0.8394, p-value = 0.0011, Normal = False
# Conc_4: W = 0.7532, p-value = 0.0059, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 186.0, p-value = 0.9528931677341461, Significant = False
# Conc_2 Wilcoxon: statistic = 136.0, p-value = 0.704756498336792, Significant = False
# Conc_3 Wilcoxon: statistic = 91.0, p-value = 0.055070459842681885, Significant = False
# Conc_4 Wilcoxon: statistic = 20.0, p-value = 0.8203125, Significant = False
# ['Name', 'Exp', 'Well', 'Conc_-1', 'Conc_1', 'Conc_2', 'Conc_3', 'Conc_4']
# Shapiro-Wilk Normality Test Results for Relaxation_time_90_(s):
# Conc_1: W = 0.4266, p-value = 0.0000, Normal = False
# Conc_2: W = 0.9127, p-value = 0.0404, Normal = False
# Conc_3: W = 0.8491, p-value = 0.0017, Normal = False
# Conc_4: W = 0.7853, p-value = 0.0139, Normal = False
# NormalGolbal=False
# Conc_1 Wilcoxon: statistic = 164.0, p-value = 0.5619325190782547, Significant = False
# Conc_2 Wilcoxon: statistic = 92.0, p-value = 0.10109639167785645, Significant = False
# Conc_3 Wilcoxon: statistic = 124.0, p-value = 0.312333345413208, Significant = False
# Conc_4 Wilcoxon: statistic = 19.0, p-value = 0.734375, Significant = False
