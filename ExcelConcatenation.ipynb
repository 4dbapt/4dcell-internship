# %% [markdown]
# ## Imports

# %%
import os
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tkinter.filedialog import askdirectory
from scipy.signal import savgol_filter, find_peaks
from scipy.integrate import trapezoid
from scipy.signal import butter, filtfilt, find_peaks
from numpy.fft import fft

# %% [markdown]
# ## Load data

# %%
# Load files
# Selecting folder to analyse (folder containing all conditions)
folder = input('Select the folder containing all the folders containing csv files to analyse')

# %% [markdown]
# ## Concatenation of all files

# %%
ConcatenatedData=pd.DataFrame()
for file in [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]: # file in folder that is not a subfolder
        # if file.endswith('_signal.csv'):
        if file.endswith('_ContractionPoints.csv'):
            Drug = os.path.join(folder, file)
            NewContractilityData = pd.read_csv(Drug)
            ConcatenatedData=pd.concat([ConcatenatedData,NewContractilityData])

# %% [markdown]
# ## Save data

# %%
# Save params as one csv for whole condition
ExpName=file.split('_')[0]+'_'+file.split('_')[1]+'_'+file.split('_')[2] # right file name to be fixed
# ExpName=file.split('_')[0]
# ExpName=file
# ConcatenatedData.to_csv(f'{folder}/{ExpName}_Concatenated_signal.csv', index=False)
ConcatenatedData.to_csv(f'{folder}/{ExpName}_ContractionPoints.csv', index=False)
